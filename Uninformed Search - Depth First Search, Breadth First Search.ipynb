# %% [markdown]
# # Uninformed Search - Depth First Search, Breadth First Search

# %% [markdown]
# ![AI-algos-1-e1547043543151.jpg](attachment:AI-algos-1-e1547043543151.jpg)

# %% [markdown]
# ![Screenshot%202023-01-26%20140908.jpg](attachment:Screenshot%202023-01-26%20140908.jpg)

# %% [markdown]
# source - https://www.geeksforgeeks.org/difference-between-informed-and-uninformed-search-in-ai/

# %% [markdown]
# # Depth First Search

# %%
# DFS algorithm
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)

    print(start)

    for next in graph[start] - visited:
        dfs(graph, next, visited)
    return visited


graph = {'0': set(['1', '2']),
         '1': set(['0', '3', '4']),
         '2': set(['0']),
         '3': set(['1']),
         '4': set(['2', '3'])}

dfs(graph, '0')
# Out:
# 0
# 2
# 1
# 3
# 4
# {'0', '1', '2', '3', '4'}

# %% [markdown]
# # Breadth First Search

# %%
import collections

# BFS algorithm
def bfs(graph, root):

    visited, queue = set(), collections.deque([root])
    visited.add(root)

    while queue:

        # Dequeue a vertex from queue
        vertex = queue.popleft()
        print(str(vertex) + " ", end="")

        # If not visited, mark it as visited, and
        # enqueue it
        for neighbour in graph[vertex]:
            if neighbour not in visited:
                visited.add(neighbour)
                queue.append(neighbour)


if __name__ == '__main__':
    graph = {0: [1, 2], 1: [2], 2: [3], 3: [1, 2]}
    print("Following is Breadth First Traversal: ")
    bfs(graph, 0)
# Out:
# Following is Breadth First Traversal:
# 0 1 2 3
